# %% [markdown]
# # SPAT 0002-1
#
#
#
# ## Content
#
# ### [About this course](01-Intro_to_python/Introduction.ipynb)
#
# ### [Linux Survival Kit](01-Intro_to_python/Intro-Linux.ipynb)
#
# - What is Linux ?
# - Why learning shell ?
# - Important shell commands
# - A few words about various shells
#
# ###  [First steps in pyhon](01-Intro_to_python/Intro-Python.ipynb)
#
# - Getting started with python: Container objects (Lists, sets, tuples, dictionaries), Functions, Control-flow statements (if, while, for)
# - Tips regarding the use of Jupyter and IDE.
# - How to [install a python distribution on my personal computer ?](Install python.ipynb)
#
# ### [Summary of the main python structures and commands](02-Main_useful_python_modules/Recap_python_L1.ipynb)
#
# - Main built-in python structures: Lists, sets, tuple, dictionaries and methods to manipulate them.
# - Control flow statements: `if`, `for`, `while`
# - Functions
# - List comprehensions
#
#
# ### [Python Modules](02-Main_useful_python_modules/Modules_in__python.ipynb)
#
# - What is a module ?
# - [Overview of `numpy`](02-Main_useful_python_modules/Modules_in__python_numpy.ipynb): array definition, shape manipulation, copies and view, reading from a txt file.
# - [Introduction to `matplotlib`](02-Main_useful_python_modules/Modules_in__python_matplotlib.ipynb): Simple plot, control of plotting properties, axes, ...
# - [Introduction to `scipy`](02-Main_useful_python_modules/Modules_in__python_scipy.ipynb): Special functions (`scipy.special`), linear algebra (`scipy.linalg`), statistics and random numbers (`scipy.stats`), interpolation (`scipy.interpolate`), physical constants (`scipy.constants`), numerical integration (`scipy.integrate`), Function minimization and fitting (`scipy.optimize`)
# - [Standard library](02-Main_useful_python_modules/Modules_in__python_numpy.ipynb): `os`, `subprocess`, `sys`
#
# ### [Astropy Basics](07-Astropy/Astropy-basics.ipynb)
#
# - Viewing and manipulating [fits images](07-Astropy/Astropy_fits_image.ipynb), [tables](07-Astropy/Astropy_fits_table.ipynb), and [headers](07-Astropy/Astropy_fits_header.ipynb) (`astropy.io.fits`)
# - Overlay image [coordinates on an image](07-Astropy/Astropy_coordinates.ipynb) (`astropy.wcs`)
# - Work with image [coordinates](07-Astropy/Astropy_coordinates.ipynb) (`astropy.coordinates.Skycoord`)
# - Use of [quantities for astrophysical calculations](07-Astropy/Astropy_quantities.ipynb) (`astropy.units`, `astropy.constants`)
#
# ### [Basic statistics and probability concepts](03-Basic statistics_and_proba_concepts/Basic-statistics_01.ipynb)
#
# - [Axiom of probability](03-Basic statistics_and_proba_concepts/Basic-statistics_01.ipynb)
# - [Conditional probability and Bayes theorem](03-Basic statistics_and_proba_concepts/Basic-statistics_01.ipynb)
# - [Concepts of random variable, PDF, CDF](03-Basic statistics_and_proba_concepts/Basic-statistics_01.ipynb)
# - [Monte-Carlo method](03-Basic statistics_and_proba_concepts/Basic-statistics_02.ipynb)
# - [Error estimate using Monte-Carlo](03-Basic statistics_and_proba_concepts/Basic-statistics_02.ipynb)
#
# ### [Descriptive statistics](03-Basic statistics_and_proba_concepts/Descriptive_statistics.ipynb)
#
# - [Quantities describing distribution functions](03-Basic statistics_and_proba_concepts/Descriptive_statistics.ipynb)
#     * Population Statistics
#     * Sample Statistics
#     * Bias of an estimator
#     * Statistics of multivariate distributions
#     * Change of variable
# - [Very common Univariate distributions](03-Basic statistics_and_proba_concepts/Descriptive_statistics.ipynb)
#     * Bernouilli distribution
#     * Uniform distribution
#     * Binomial distribution
#     * Hypergeometric distribution
#     * Poisson distribution
#     * Geometric distribution
#     * Gaussian distribution
#     * Chi2 distribution
#     * Student's distribution
#
# ### [Frequentist inference](04-Basic_statistical_inference_frequentists_2/Frequentist_inference.ipynb)
#
# - Point estimate
#     * Summary of useful statistics
#     * Distributions of estimators
# - Confidence interval
#     * Normal distribution with a known variance
#     * Interpretation of CI
#     * Normal distribution with an unknown variance
#     * Confidence interval for variances
#     * Confidence interval between 2 means
#     * Confidence interval for proportions
# - Hypothesis testing
#     * Student's t test
#     * Paired test to compare means ot 2 dependent populations
#     * Paired test for means of 2 independent populations
#     * What to do if the population distributions are not gaussian ?
#     * Hypothesis testing for proportions
# - Bootstrap and Jacknife
#
# ### [Frequentist inference: MLE, regression, bootstraping](05-MLE_and_regression_freqentists_3/MLE_and_regression.ipynb)
#
# - Maximum Likelihood estimation (MLE)
# - Properties of MLE estimators
# - Regression and model fitting: Linear models, regularization and penalization of the likelihood, Non-linear models
#
# ### [Bayesian inference](06-Bayesian_inference_MCMC/Bayes_inference_MCMC.ipynb)
#
# - Difference between Bayesian and Frequentist inference
# - Principles and Bayesian inference
# - The Bayes theorem
# - Simple Bayesian modeling: Fitting a line to data
# - Bayesian modeling with MCMC
#
#
# ### [Make your own MCMC](06-Bayesian_inference_MCMC/Exr-Make_your_own_MCM.ipynb)
#
# - Metropolis Hastings procedure step by step.
#
#
# ## Software requirements
#
# Those notebooks require installation of:
# - numpy
# - os, subprocess, sys
# - scipy
# - matplotlib
# - astroML
# - astropy
# - ipywidget
# - random
